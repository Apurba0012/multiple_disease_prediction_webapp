# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
from tensorflow. keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn. model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %%
print(tf. __version__)
# Out:
# 2.12.0

# %% [markdown]
# # Defining the path of dataset directory

# %%
dataset_path = "F:/python code/temporary/dataset/chest_xray/train"

# %%
# Plotting 12 images to check dataset

plt.figure(figsize = (12, 12))
dataset_path = "F:/python code/temporary/dataset/chest_xray/train/PNEUMONIA"

for i in range(1, 17):
    plt.subplot(4, 4, i)
    plt.tight_layout()
    rand_img = imread(dataset_path +'/'+ random.choice(sorted(os.listdir(dataset_path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10) # width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10) # height of image

# %% [markdown]
# # Convert the images into a Numpy array and normalize them

# %%
# Converting Images to array 

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256, 256))  
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dataset_path = "F:/python code/temporary/dataset/chest_xray/train"
labels = os.listdir(dataset_path)

print(labels)
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
dataset_path = "F:/python code/temporary/dataset/chest_xray/train"
root_dir = listdir(dataset_path)
image_list, label_list = [], []
all_labels = ['NORMAL', 'PNEUMONIA']
binary_labels = [0, 1]
temp = -1

# Reading and converting image to numpy array

for directory in root_dir:
  plant_image_list = listdir(f"{dataset_path}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dataset_path}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# # Visualize the class count and Check for class imbalance

# %%
# Visualize the number of classes count

label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    1340
# 1    1340
# dtype: int64

# %%
# Next we will observe the shape of the image.

image_list[0].shape
# Out:
# (256, 256, 3)

# %%
# Checking the total number of the images which is the length of the labels list.

label_list = np.array(label_list)
label_list.shape
# Out:
# (2680,)

# %% [markdown]
# # Splitting the dataset into train, validate and test sets

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape(-1, 256, 256, 3)
x_test = x_test.reshape(-1, 256, 256, 3)

# %% [markdown]
# # Performing one-hot encoding on target variable

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# Splitting the training data set into training and validation data sets

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 10)

# %% [markdown]
# # Creating the model architecture, compile the model and then fit it using the training data

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding = "same",input_shape = (256, 256, 3), activation = "relu"))
model.add(MaxPooling2D(pool_size = (3, 3)))
model.add(Conv2D(32, (3, 3), padding = "same", activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(128, activation = "relu"))
model.add(Dense(2, activation = "softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 256, 256, 64)      1792
#
#  max_pooling2d_2 (MaxPooling  (None, 85, 85, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 85, 85, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 42, 42, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 56448)             0
#
#  dense_2 (Dense)             (None, 128)               7225472
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 7,245,986
# Trainable params: 7,245,986
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001), metrics = ['accuracy'])

# %%
# Training the model

epochs = 20
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/20
# 14/14 [==============================] - 122s 8s/step - loss: 0.5222 - accuracy: 0.8012 - val_loss: 0.4439 - val_accuracy: 0.8578
# Epoch 2/20
# 14/14 [==============================] - 98s 7s/step - loss: 0.3589 - accuracy: 0.8863 - val_loss: 0.3549 - val_accuracy: 0.8531
# Epoch 3/20
# 14/14 [==============================] - 94s 7s/step - loss: 0.2742 - accuracy: 0.9009 - val_loss: 0.2581 - val_accuracy: 0.8951
# Epoch 4/20
# 14/14 [==============================] - 92s 7s/step - loss: 0.2171 - accuracy: 0.9259 - val_loss: 0.2148 - val_accuracy: 0.9114
# Epoch 5/20
# 14/14 [==============================] - 95s 7s/step - loss: 0.1764 - accuracy: 0.9359 - val_loss: 0.2418 - val_accuracy: 0.9114
# Epoch 6/20
# 14/14 [==============================] - 95s 7s/step - loss: 0.1718 - accuracy: 0.9359 - val_loss: 0.1319 - val_accuracy: 0.9580
# Epoch 7/20
# 14/14 [==============================] - 92s 7s/step - loss: 0.1259 - accuracy: 0.9598 - val_loss: 0.1116 - val_accuracy: 0.9650
# Epoch 8/20
# 14/14 [==============================] - 92s 6s/step - loss: 0.1056 - accuracy: 0.9673 - val_loss: 0.1032 - val_accuracy: 0.9627
# Epoch 9/20
# 14/14 [==============================] - 94s 7s/step - loss: 0.0944 - accuracy: 0.9708 - val_loss: 0.0914 - val_accuracy: 0.9674
# Epoch 10/20
# 14/14 [==============================] - 92s 7s/step - loss: 0.0849 - accuracy: 0.9743 - val_loss: 0.0817 - val_accuracy: 0.9767
# Epoch 11/20
# 14/14 [==============================] - 91s 7s/step - loss: 0.0789 - accuracy: 0.9726 - val_loss: 0.0824 - val_accuracy: 0.9767
# Epoch 12/20
# 14/14 [==============================] - 90s 6s/step - loss: 0.0714 - accuracy: 0.9778 - val_loss: 0.0703 - val_accuracy: 0.9790
# Epoch 13/20
# 14/14 [==============================] - 96s 7s/step - loss: 0.0622 - accuracy: 0.9784 - val_loss: 0.0656 - val_accuracy: 0.9720
# Epoch 14/20
# 14/14 [==============================] - 92s 7s/step - loss: 0.0576 - accuracy: 0.9825 - val_loss: 0.0615 - val_accuracy: 0.9697
# Epoch 15/20
# 14/14 [==============================] - 95s 7s/step - loss: 0.0655 - accuracy: 0.9796 - val_loss: 0.0679 - val_accuracy: 0.9744
# Epoch 16/20
# 14/14 [==============================] - 94s 7s/step - loss: 0.0643 - accuracy: 0.9790 - val_loss: 0.0636 - val_accuracy: 0.9790
# Epoch 17/20
# 14/14 [==============================] - 94s 7s/step - loss: 0.0535 - accuracy: 0.9813 - val_loss: 0.0599 - val_accuracy: 0.9720
# Epoch 18/20
# 14/14 [==============================] - 94s 7s/step - loss: 0.0432 - accuracy: 0.9854 - val_loss: 0.0615 - val_accuracy: 0.9814
# Epoch 19/20
# 14/14 [==============================] - 93s 7s/step - loss: 0.0433 - accuracy: 0.9854 - val_loss: 0.0600 - val_accuracy: 0.9814
# Epoch 20/20
# 14/14 [==============================] - 95s 7s/step - loss: 0.0378 - accuracy: 0.9889 - val_loss: 0.0551 - val_accuracy: 0.9814

# %%
model.save("F:/python code/temporary/model/PNEUMONIA_prediction_model.h5")

# %%
# Plot the training history

plt.figure(figsize = (12, 5))
plt.plot(history.history['accuracy'], color = 'r')
plt.plot(history.history['val_accuracy'], color = 'b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("Calculating model accuracy")

scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1] * 100}")
# Out:
# Calculating model accuracy
# 17/17 [==============================] - 6s 326ms/step - loss: 0.0891 - accuracy: 0.9757
# Test Accuracy: 97.57462739944458

# %%
y_pred = model.predict(x_test)
# Out:
# 17/17 [==============================] - 7s 368ms/step

# %%
# Plotting image to compare

img = array_to_img(x_test[11])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted

print("Originally : ", all_labels[np.argmax(y_test[11])])
print("Predicted : ", all_labels[np.argmax(y_pred[1])])
print(y_pred[2])
# Out:
# Originally :  PNEUMONIA
# Predicted :  PNEUMONIA
# [0.98472023 0.01527974]

# %%
for i in range(16):
    print (all_labels[np.argmax(y_test[i])], " ", all_labels[np.argmax(y_pred [2])])
# Out:
# NORMAL   NORMAL
# PNEUMONIA   NORMAL
# NORMAL   NORMAL
# PNEUMONIA   NORMAL
# NORMAL   NORMAL
# NORMAL   NORMAL
# PNEUMONIA   NORMAL
# NORMAL   NORMAL
# PNEUMONIA   NORMAL
# NORMAL   NORMAL
# NORMAL   NORMAL
# PNEUMONIA   NORMAL
# NORMAL   NORMAL
# NORMAL   NORMAL
# NORMAL   NORMAL
# NORMAL   NORMAL
