# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
from tensorflow. keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn. model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %%
print(tf. __version__)
# Out:
# 2.12.0

# %% [markdown]
# # Defining the path of dataset directory

# %%
dataset_path = "F:/python code/temporary/Dataset01/tomato/train01"

# %%
# Plotting 12 images to check dataset

plt.figure(figsize = (12, 12))
dataset_path = "F:/python code/temporary/Dataset01/tomato/train01/Tomato - Early_blight"

for i in range(1, 17):
    plt.subplot(4, 4, i)
    plt.tight_layout()
    rand_img = imread(dataset_path +'/'+ random.choice(sorted(os.listdir(dataset_path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10) # width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10) # height of image

# %% [markdown]
# # Convert the images into a Numpy array and normalize them

# %%
# Converting Images to array 

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256, 256))  
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dataset_path = "F:/python code/temporary/Dataset01/tomato/train01"
labels = os.listdir(dataset_path)

print(labels)
# Out:
# ['Tomato - Early_blight', 'Tomato - Healthy', 'Tomato - Septoria_leaf_spot', 'Tomato - Tomato_Yellow_Leaf_Curl_Virus']

# %%
dataset_path = "F:/python code/temporary/Dataset01/tomato/train01"
root_dir = listdir(dataset_path)
image_list, label_list = [], []
all_labels = ['Tomato - Early_blight', 'Tomato - Healthy', 'Tomato - Septoria_leaf_spot', 'Tomato - Tomato_Yellow_Leaf_Curl_Virus']
binary_labels = [0, 1, 2,3]
temp = -1

# Reading and converting image to numpy array

for directory in root_dir:
  plant_image_list = listdir(f"{dataset_path}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dataset_path}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# # Visualize the class count and Check for class imbalance

# %%
# Visualize the number of classes count

label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    20
# 1    20
# 2    20
# 3    20
# dtype: int64

# %%
label_counts.tail()
# Out:
# 0    20
# 1    20
# 2    20
# 3    20
# dtype: int64

# %% [raw]
# # it is a balanced dataset as we can see

# %%
# Next we will observe the shape of the image.

image_list[0].shape
# Out:
# (256, 256, 3)

# %%
# Checking the total number of the images which is the length of the labels list.

label_list = np.array(label_list)
label_list.shape
# Out:
# (80,)

# %% [markdown]
# # Splitting the dataset into train, validate and test sets

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape(-1, 256, 256, 3)
x_test = x_test.reshape(-1, 256, 256, 3)

# %% [markdown]
# # Performing one-hot encoding on target variable

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# Splitting the training data set into training and validation data sets

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 10)

# %% [markdown]
# # Creating the model architecture, compile the model and then fit it using the training data

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding = "same",input_shape = (256, 256, 3), activation = "relu"))
model.add(MaxPooling2D(pool_size = (3, 3)))
model.add(Conv2D(32, (3, 3), padding = "same", activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(80, activation = "relu"))
model.add(Dense(4, activation = "softmax"))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 256, 256, 64)      1792
#
#  max_pooling2d_6 (MaxPooling  (None, 85, 85, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 85, 85, 32)        18464
#
#  max_pooling2d_7 (MaxPooling  (None, 42, 42, 32)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 56448)             0
#
#  dense_6 (Dense)             (None, 128)               7225472
#
#  dense_7 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 7,246,244
# Trainable params: 7,246,244
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.00001), metrics = ['accuracy'])

# %%
# Training the model

epochs = 300
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/300
# 1/1 [==============================] - 4s 4s/step - loss: 0.8570 - accuracy: 0.9412 - val_loss: 1.0937 - val_accuracy: 0.7692
# Epoch 2/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.8455 - accuracy: 0.9412 - val_loss: 1.0849 - val_accuracy: 0.7692
# Epoch 3/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.8339 - accuracy: 0.9412 - val_loss: 1.0792 - val_accuracy: 0.7692
# Epoch 4/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.8222 - accuracy: 0.9412 - val_loss: 1.0719 - val_accuracy: 0.7692
# Epoch 5/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.8109 - accuracy: 0.9412 - val_loss: 1.0604 - val_accuracy: 0.8462
# Epoch 6/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7996 - accuracy: 0.9412 - val_loss: 1.0478 - val_accuracy: 0.8462
# Epoch 7/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.7883 - accuracy: 0.9412 - val_loss: 1.0368 - val_accuracy: 0.8462
# Epoch 8/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.7771 - accuracy: 0.9412 - val_loss: 1.0281 - val_accuracy: 0.8462
# Epoch 9/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7660 - accuracy: 0.9412 - val_loss: 1.0214 - val_accuracy: 0.8462
# Epoch 10/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7550 - accuracy: 0.9412 - val_loss: 1.0142 - val_accuracy: 0.8462
# Epoch 11/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7442 - accuracy: 0.9412 - val_loss: 1.0052 - val_accuracy: 0.8462
# Epoch 12/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7334 - accuracy: 0.9412 - val_loss: 0.9944 - val_accuracy: 0.8462
# Epoch 13/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7227 - accuracy: 0.9412 - val_loss: 0.9834 - val_accuracy: 0.8462
# Epoch 14/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7121 - accuracy: 0.9412 - val_loss: 0.9732 - val_accuracy: 0.8462
# Epoch 15/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.7017 - accuracy: 0.9412 - val_loss: 0.9653 - val_accuracy: 0.8462
# Epoch 16/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.6913 - accuracy: 0.9412 - val_loss: 0.9589 - val_accuracy: 0.8462
# Epoch 17/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.6811 - accuracy: 0.9412 - val_loss: 0.9514 - val_accuracy: 0.8462
# Epoch 18/300
# 1/1 [==============================] - 3s 3s/step - loss: 0
300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9231
# Epoch 196/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.2611 - val_accuracy: 0.9231
# Epoch 197/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 0.2604 - val_accuracy: 0.9231
# Epoch 198/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.2596 - val_accuracy: 0.9231
# Epoch 199/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9231
# Epoch 200/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0424 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9231
# Epoch 201/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0419 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9231
# Epoch 202/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0414 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9231
# Epoch 203/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.2551 - val_accuracy: 0.9231
# Epoch 204/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0404 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.9231
# Epoch 205/300
# 1/1 [==============================] - 4s 4s/step - loss: 0.0399 - accuracy: 1.0000 - val_loss: 0.2540 - val_accuracy: 0.9231
# Epoch 206/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.2535 - val_accuracy: 0.9231
# Epoch 207/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.2528 - val_accuracy: 0.9231
# Epoch 208/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0385 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9231
# Epoch 209/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9231
# Epoch 210/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9231
# Epoch 211/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9231
# Epoch 212/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9231
# Epoch 213/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.2488 - val_accuracy: 0.9231
# Epoch 214/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.2482 - val_accuracy: 0.9231
# Epoch 215/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.2474 - val_accuracy: 0.9231
# Epoch 216/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.2468 - val_accuracy: 0.9231
# Epoch 217/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.2460 - val_accuracy: 0.9231
# Epoch 218/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9231
# Epoch 219/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.2446 - val_accuracy: 0.9231
# Epoch 220/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.2440 - val_accuracy: 0.9231
# Epoch 221/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9231
# Epoch 222/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.2428 - val_accuracy: 0.9231
# Epoch 223/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.9231
# Epoch 224/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.2417 - val_accuracy: 0.9231
# Epoch 225/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.2412 - val_accuracy: 0.9231
# Epoch 226/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9231
# Epoch 227/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.2400 - val_accuracy: 0.9231
# Epoch 228/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.2393 - val_accuracy: 0.9231
# Epoch 229/300
# 1/1 [==============================] - 4s 4s/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.9231
# Epoch 230/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.9231
# Epoch 231/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.2373 - val_accuracy: 0.9231
# Epoch 232/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.2369 - val_accuracy: 0.9231
# Epoch 233/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.2361 - val_accuracy: 0.9231
# Epoch 234/300
# 1/1 [==============================] - 4s 4s/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9231
# Epoch 235/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9231
# Epoch 236/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9231
# Epoch 237/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.2335 - val_accuracy: 0.9231
# Epoch 238/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9231
# Epoch 239/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9231
# Epoch 240/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9231
# Epoch 241/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9231
# Epoch 242/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9231
# Epoch 243/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9231
# Epoch 244/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.2293 - val_accuracy: 0.9231
# Epoch 245/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9231
# Epoch 246/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9231
# Epoch 247/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9231
# Epoch 248/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9231
# Epoch 249/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9231
# Epoch 250/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9231
# Epoch 251/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9231
# Epoch 252/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.2239 - val_accuracy: 0.9231
# Epoch 253/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9231
# Epoch 254/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9231
# Epoch 255/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9231
# Epoch 256/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9231
# Epoch 257/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9231
# Epoch 258/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.9231
# Epoch 259/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9231
# Epoch 260/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.2194 - val_accuracy: 0.9231
# Epoch 261/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.9231
# Epoch 262/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9231
# Epoch 263/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.2182 - val_accuracy: 0.9231
# Epoch 264/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.2176 - val_accuracy: 0.9231
# Epoch 265/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.2171 - val_accuracy: 0.9231
# Epoch 266/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.2165 - val_accuracy: 0.9231
# Epoch 267/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.2160 - val_accuracy: 0.9231
# Epoch 268/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9231
# Epoch 269/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9231
# Epoch 270/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9231
# Epoch 271/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9231
# Epoch 272/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9231
# Epoch 273/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9231
# Epoch 274/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9231
# Epoch 275/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9231
# Epoch 276/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9231
# Epoch 277/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9231
# Epoch 278/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9231
# Epoch 279/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9231
# Epoch 280/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9231
# Epoch 281/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9231
# Epoch 282/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9231
# Epoch 283/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9231
# Epoch 284/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9231
# Epoch 285/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9231
# Epoch 286/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9231
# Epoch 287/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9231
# Epoch 288/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9231
# Epoch 289/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9231
# Epoch 290/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9231
# Epoch 291/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9231
# Epoch 292/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9231
# Epoch 293/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9231
# Epoch 294/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9231
# Epoch 295/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9231
# Epoch 296/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9231
# Epoch 297/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9231
# Epoch 298/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9231
# Epoch 299/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9231
# Epoch 300/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9231

# %%
model.save("F:/python code/temporary/model/tomato_disease_prediction_model.h5")

# %% [markdown]
# # Plot the accuracy and loss against each epoch

# %%
# Plot the training history

plt.figure(figsize = (12, 5))
plt.plot(history.history['accuracy'], color = 'r')
plt.plot(history.history['val_accuracy'], color = 'b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("Calculating model accuracy")

scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1] * 100}")
# Out:
# Calculating model accuracy
# 1/1 [==============================] - 0s 222ms/step - loss: 0.1903 - accuracy: 0.9375
# Test Accuracy: 93.75

# %% [markdown]
# # Make predictions on testing data

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 316ms/step

# %% [markdown]
# # Visualizing the original and predicted labels for the test images

# %%
# Plotting image to compare

img = array_to_img(x_test[11])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted

print("Originally : ", all_labels[np.argmax(y_test[11])])
print("Predicted : ", all_labels[np.argmax(y_pred[4])])
print(y_pred[2])
# Out:
# Originally :  Tomato - Healthy
# Predicted :  Tomato - Healthy
# [0.00250329 0.9835164  0.01265819 0.0013222 ]

# %%
for i in range(16):
    print (all_labels[np.argmax(y_test[i])], " ", all_labels[np.argmax(y_pred [1])])
# Out:
# Tomato - Septoria_leaf_spot   Tomato - Septoria_leaf_spot
# Tomato - Septoria_leaf_spot   Tomato - Septoria_leaf_spot
# Tomato - Healthy   Tomato - Septoria_leaf_spot
# Tomato - Healthy   Tomato - Septoria_leaf_spot
# Tomato - Healthy   Tomato - Septoria_leaf_spot
# Tomato - Tomato_Yellow_Leaf_Curl_Virus   Tomato - Septoria_leaf_spot
# Tomato - Healthy   Tomato - Septoria_leaf_spot
# Tomato - Early_blight   Tomato - Septoria_leaf_spot
# Tomato - Healthy   Tomato - Septoria_leaf_spot
# Tomato - Early_blight   Tomato - Septoria_leaf_spot
# Tomato - Septoria_leaf_spot   Tomato - Septoria_leaf_spot
# Tomato - Healthy   Tomato - Septoria_leaf_spot
# Tomato - Septoria_leaf_spot   Tomato - Septoria_leaf_spot
# Tomato - Tomato_Yellow_Leaf_Curl_Virus   Tomato - Septoria_leaf_spot
# Tomato - Early_blight   Tomato - Septoria_leaf_spot
# Tomato - Early_blight   Tomato - Septoria_leaf_spot
